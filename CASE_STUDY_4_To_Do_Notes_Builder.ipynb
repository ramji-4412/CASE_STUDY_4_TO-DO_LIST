# %% [markdown]
# <a href="https://colab.research.google.com/github/ramji-4412/CASE_STUDY_4_TO-DO_LIST/blob/main/CASE_STUDY_4_To_Do_Notes_Builder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
task_list = []

def add_task():
    task = input("Enter your task to add: ")
    task_list.append({"description": task, "completed": False})
    print("Task Added Successfully\n")

def view_task():
    if len(task_list) == 0:
        print("No tasks found.\n")
    else:
        i = 0
        while i < len(task_list):
            task = task_list[i]
            if task["completed"]:
                status = "[✓]"
            else:
                status = "[ ]"
            print(str(i + 1).zfill(2) + ". " + status + " " + task["description"])
            i = i + 1
        print()

def delete_task():
    view_task()
    task_no = input("Enter the task number to delete: ")
    if task_no.isdigit():
        task_no = int(task_no)
        if task_no >= 1 and task_no <= len(task_list):
            del task_list[task_no - 1]
            print("Task Deleted Successfully\n")
        else:
            print("Invalid task number.\n")
    else:
        print("Please enter a valid number.\n")

def mark_as_complete():
    view_task()
    task_no = input("Enter the task number to mark as complete: ")
    if task_no.isdigit():
        task_no = int(task_no)
        if task_no >= 1 and task_no <= len(task_list):
            task_list[task_no - 1]["completed"] = True
            print("Task Marked as Complete\n")
        else:
            print("Invalid task number.\n")
    else:
        print("Please enter a valid number.\n")

# Main loop
while True:
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Delete Task")
    print("4. Mark Task as Complete")
    print("5. Exit")

    choice = input("Enter your choice: ")
    if choice.isdigit():
        choice = int(choice)
        if choice == 1:
            add_task()
        elif choice == 2:
            view_task()
        elif choice == 3:
            delete_task()
        elif choice == 4:
            mark_as_complete()
        elif choice == 5:
            print("Goodbye!")
            break
        else:
            print("Invalid choice. Please choose between 1 and 5.\n")
    else:
        print("Please enter a number.\n")
W
# Out:
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Mark Task as Complete
# 5. Exit
# Enter your choice: 1
# Enter your task to add: Play
# Task Added Successfully
#
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Mark Task as Complete
# 5. Exit
# Enter your choice: 1
# Enter your task to add: Study
# Task Added Successfully
#
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Mark Task as Complete
# 5. Exit
# Enter your choice: 1
# Enter your task to add: Writing
# Task Added Successfully
#
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Mark Task as Complete
# 5. Exit
# Enter your choice: 1
# Enter your task to add: Dancing
# Task Added Successfully
#
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Mark Task as Complete
# 5. Exit
# Enter your choice: 1
# Enter your task to add: sINGING
# Task Added Successfully
#
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Mark Task as Complete
# 5. Exit
# Enter your choice: 2
# 01. [ ] Play
# 02. [ ] Study
# 03. [ ] Writing
# ...
